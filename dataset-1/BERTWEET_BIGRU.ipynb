# %%
# !pip install contractions beautifulsoup4 scikit-learn transformers torch pandas numpy nltk joblib "accelerate>=0.21.0"

# %%
import pandas as pd
import numpy as np
import re
import contractions
from bs4 import BeautifulSoup
import nltk
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from transformers import (
    AutoTokenizer,
    AutoModel,
    Trainer,
    TrainingArguments
)
from transformers.modeling_outputs import SequenceClassifierOutput
import joblib


try:
    nltk.data.find('tokenizers/punkt')
except nltk.downloader.DownloadError:
    nltk.download('punkt')

# %%
try:
    train_df = pd.read_csv('emotion-labels-train.csv')
    val_df = pd.read_csv('emotion-labels-val.csv')
    test_df = pd.read_csv('emotion-labels-test.csv')
    print("Train, validation, and test files loaded successfully.")
    print(f"Train samples: {len(train_df)}")
    print(f"Validation samples: {len(val_df)}")
    print(f"Test samples: {len(test_df)}")
except FileNotFoundError:
    print("Error: Dataset files not found. Creating dummy data for demonstration.")
    train_df = pd.DataFrame({'text': ['I love this!', 'I am so happy today'], 'label': ['joy', 'joy']})
    val_df = pd.DataFrame({'text': ['This is terrible', 'I feel sad'], 'label': ['sadness', 'sadness']})
    test_df = pd.DataFrame({'text': ['What a wonderful experience', 'I am heartbroken'], 'label': ['joy', 'sadness']})
# Out:
# Train, validation, and test files loaded successfully.
# Train samples: 3613
# Validation samples: 347
# Test samples: 3142

# %%
# Preprocessing functions
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    stripped_text = re.sub(r'[\r|\n|\r\n]+', ' ', stripped_text)
    return stripped_text

def remove_accented_chars(text):
    text = text.encode('ascii', 'ignore').decode('utf-8')
    return text

def expand_contractions(text):
    return contractions.fix(text)

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-Z0-9\s]' if not remove_digits else r'[^a-zA-Z\s]'
    text = re.sub(pattern, '', text)
    return text

def pre_process_document(document):
    document = strip_html_tags(document)
    document = document.lower()
    document = expand_contractions(document)
    document = remove_accented_chars(document)
    document = remove_special_characters(document, remove_digits=True)
    return document

# %%
# Apply preprocessing to each split
print("\nApplying preprocessing to all data splits...")
for df in [train_df, val_df, test_df]:
    df['cleaned_text'] = df['text'].apply(pre_process_document)

# Label Encoding
le = LabelEncoder()
train_df['label_encoded'] = le.fit_transform(train_df['label'])
val_df['label_encoded'] = le.transform(val_df['label'])
test_df['label_encoded'] = le.transform(test_df['label'])

# Prepare data for tokenization
X_train, y_train = train_df['cleaned_text'].tolist(), train_df['label_encoded'].tolist()
X_val, y_val = val_df['cleaned_text'].tolist(), val_df['label_encoded'].tolist()
X_test, y_test = test_df['cleaned_text'].tolist(), test_df['label_encoded'].tolist()

print("\nData preprocessing complete.")
print(f"Labels: {list(le.classes_)}")
num_labels = len(le.classes_)
# Out:
# Applying preprocessing to all data splits...
#
# Data preprocessing complete.
# Labels: ['anger', 'fear', 'joy', 'sadness']

# %%
MODEL_NAME = "vinai/bertweet-base"
tokenizer_bert = AutoTokenizer.from_pretrained(MODEL_NAME, normalization=True)

train_encodings = tokenizer_bert(X_train, truncation=True, padding=True, max_length=128)
val_encodings = tokenizer_bert(X_val, truncation=True, padding=True, max_length=128)
test_encodings = tokenizer_bert(X_test, truncation=True, padding=True, max_length=128)
# Out:
# config.json:   0%|          | 0.00/558 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
class EmotionDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = EmotionDataset(train_encodings, y_train)
val_dataset = EmotionDataset(val_encodings, y_val)
test_dataset = EmotionDataset(test_encodings, y_test)

# %%
class BERTweetGRUClassifier(nn.Module):
    def __init__(self, num_labels):
        super(BERTweetGRUClassifier, self).__init__()
        self.num_labels = num_labels

        self.bertweet = AutoModel.from_pretrained(MODEL_NAME, return_dict=True)
        self.gru = nn.GRU(
            input_size=self.bertweet.config.hidden_size,
            hidden_size=256,
            num_layers=2,
            batch_first=True,
            bidirectional=True,
            dropout=0.2
        )
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(256 * 2, num_labels)

    def forward(self, input_ids, attention_mask, labels=None):
        bert_outputs = self.bertweet(input_ids=input_ids, attention_mask=attention_mask)
        sequence_output = bert_outputs.last_hidden_state

        _, gru_hidden_state = self.gru(sequence_output)
        gru_output_cat = torch.cat((gru_hidden_state[-2, :, :], gru_hidden_state[-1, :, :]), dim=1)
        dropped_output = self.dropout(gru_output_cat)
        logits = self.classifier(dropped_output)

        loss = None
        if labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))

        return SequenceClassifierOutput(loss=loss, logits=logits)

print("\nInitializing custom BERTweet+GRU model...")
model_bert_gru = BERTweetGRUClassifier(num_labels=num_labels)
# Out:
# Initializing custom BERTweet+GRU model...
# pytorch_model.bin:   0%|          | 0.00/543M [00:00<?, ?B/s]

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, average='weighted')
    return {"accuracy": acc, "f1": f1}

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=10,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=64,
    fp16=True,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=50,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,
    disable_tqdm=False
)

trainer = Trainer(
    model=model_bert_gru,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

# %%
print("\nTraining BERTweet+GRU model...")
trainer.train()
# Out:
# Training BERTweet+GRU model...
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: paradox117 (paradox117-jadavpur-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# ...

# %%
# --- BERTweet-only classifier ---
class BERTweetClassifier(nn.Module):
    def __init__(self, num_labels):
        super(BERTweetClassifier, self).__init__()
        self.num_labels = num_labels
        self.bertweet = AutoModel.from_pretrained(MODEL_NAME, return_dict=True)
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(self.bertweet.config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask, labels=None):
        bert_outputs = self.bertweet(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = bert_outputs.last_hidden_state[:, 0, :]  # Use [CLS] token representation
        dropped_output = self.dropout(pooled_output)
        logits = self.classifier(dropped_output)

        loss = None
        if labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))

        return SequenceClassifierOutput(loss=loss, logits=logits)

print("\nInitializing plain BERTweet model...")
model_bert_only = BERTweetClassifier(num_labels=num_labels)
# Out:
# Initializing plain BERTweet model...

# %%
trainer_bert_only = Trainer(
    model=model_bert_only,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

# %%
print("\nTraining plain BERTweet model...")
trainer_bert_only.train()
# Out:
# Training plain BERTweet model...
#     <div>
#
#       <progress value='1130' max='1130' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1130/1130 08:40, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.373400</td>
#       <td>1.347024</td>
#       <td>0.334294</td>
#       <td>0.192603</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.111200</td>
#       <td>0.609546</td>
#       <td>0.812680</td>
#       <td>0.812243</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.470900</td>
#       <td>0.372063</td>
#       <td>0.867435</td>
#       <td>0.868390</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.300400</td>
#       <td>0.378767</td>
# ...

# %%
# --- Evaluate BERTweet+GRU ---
print("\nEvaluating BERTweet+GRU on validation set...")
val_results_gru = trainer.evaluate(eval_dataset=val_dataset)
print("\nValidation Results (BERTweet+GRU):")
for key, value in val_results_gru.items():
    print(f"{key}: {value:.4f}")

print("\nEvaluating BERTweet+GRU on test set...")
test_results_gru = trainer.evaluate(eval_dataset=test_dataset)
print("\nTest Results (BERTweet+GRU):")
for key, value in test_results_gru.items():
    print(f"{key}: {value:.4f}")

# --- Evaluate plain BERTweet ---
print("\nEvaluating plain BERTweet on validation set...")
val_results_plain = trainer_bert_only.evaluate(eval_dataset=val_dataset)
print("\nValidation Results (BERTweet-only):")
for key, value in val_results_plain.items():
    print(f"{key}: {value:.4f}")

print("\nEvaluating plain BERTweet on test set...")
test_results_plain = trainer_bert_only.evaluate(eval_dataset=test_dataset)
print("\nTest Results (BERTweet-only):")
for key, value in test_results_plain.items():
    print(f"{key}: {value:.4f}")
# Out:
# Evaluating BERTweet+GRU on validation set...
#     <div>
#
#       <progress value='112' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 12:15]
#     </div>
# Validation Results (BERTweet+GRU):
# eval_loss: 0.4532
# eval_accuracy: 0.8905
# eval_f1: 0.8907
# eval_runtime: 0.2852
# eval_samples_per_second: 1216.4960
# eval_steps_per_second: 21.0350
# epoch: 10.0000
#
# Evaluating BERTweet+GRU on test set...
#
# Test Results (BERTweet+GRU):
# eval_loss: 0.4861
# eval_accuracy: 0.8711
# eval_f1: 0.8716
# eval_runtime: 2.4308
# eval_samples_per_second: 1292.5910
# eval_steps_per_second: 20.5700
# epoch: 10.0000
#
# Evaluating plain BERTweet on validation set...
#     <div>
#
#       <progress value='56' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6/6 00:02]
#     </div>
# Validation Results (BERTweet-only):
# eval_loss: 0.4768
# eval_accuracy: 0.8790
# eval_f1: 0.8791
# eval_runtime: 0.3305
# ...

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define paths in your Drive
drive_base_path = "/content/drive/MyDrive/emotion_models_14-Oct"
os.makedirs(drive_base_path, exist_ok=True)

bert_gru_path = os.path.join(drive_base_path, "bertweet-gru-emotion-model")
bert_only_path = os.path.join(drive_base_path, "bertweet-only-emotion-model")
label_encoder_path = os.path.join(drive_base_path, "label_encoder.pkl")
# Out:
# Mounted at /content/drive

# %%
# Save BERTweet+GRU
trainer.save_model(bert_gru_path)
tokenizer_bert.save_pretrained(bert_gru_path)

# Save BERTweet-only
trainer_bert_only.save_model(bert_only_path)
tokenizer_bert.save_pretrained(bert_only_path)  # same tokenizer

# Save Label Encoder
joblib.dump(le, label_encoder_path)

print(f"Models and label encoder saved to Google Drive at '{drive_base_path}'")
# Out:
# Models and label encoder saved to Google Drive at '/content/drive/MyDrive/emotion_models_14-Oct'

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import torch

def get_preds_labels(model, dataset):
    """Get predicted labels and true labels for a dataset"""
    model.eval()
    preds = []
    labels = []
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=64)

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(model.bertweet.device)
            attention_mask = batch['attention_mask'].to(model.bertweet.device)
            label = batch['labels'].to(model.bertweet.device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            batch_preds = torch.argmax(logits, dim=1)

            preds.extend(batch_preds.cpu().numpy())
            labels.extend(label.cpu().numpy())
    return np.array(preds), np.array(labels)

def plot_conf_matrix(y_true, y_pred, title, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes, cmap="Blues")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(title)
    plt.show()

# %%
# Device setup
device = "cuda" if torch.cuda.is_available() else "cpu"
model_bert_gru.to(device)

datasets = {"Train": train_dataset, "Validation": val_dataset, "Test": test_dataset}

for split_name, dataset in datasets.items():
    preds, labels_true = get_preds_labels(model_bert_gru, dataset)
    plot_conf_matrix(labels_true, preds, f"BERTweet+GRU Confusion Matrix ({split_name})", le.classes_)

# %%
model_bert_only.to(device)

for split_name, dataset in datasets.items():
    preds, labels_true = get_preds_labels(model_bert_only, dataset)
    plot_conf_matrix(labels_true, preds, f"BERTweet-only Confusion Matrix ({split_name})", le.classes_)
